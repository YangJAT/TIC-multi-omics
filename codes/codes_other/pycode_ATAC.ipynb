# %% [markdown]
# # ATAC data analysis

# %% [markdown]
# 2023/6/20 by Yang Chen

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %%
import os
wdir = "/home/ug0302/CITEseq3/06_ATAC2"
os.chdir(wdir)

# %%
# %%bash
#
# input="/home/ug0302/CITEseq3/06_ATAC2/bam"
# output="/home/ug0302/CITEseq3/06_ATAC2/bam"
# file=$(ls ${input}/*.bam)
#
# for i in $file
# do
#     filename=$(basename "$i" .bam)
#     fileflt=${output}/${filename}_mt.bam
#     samtools view -@ 20 -h ${i} | grep -v chrM | samtools sort -@ 20 -O bam -o ${fileflt}
# done

# %%
# %%bash
#
# input="/home/ug0302/CITEseq3/06_ATAC2/bam"
# output="/home/ug0302/CITEseq3/06_ATAC2/bam"
# file=$(ls ${input}/*mt.bam)
#
# for i in $file
# do
#     filename=$(basename "$i" .bam)
#     fileflt=${output}/${filename}_mp.bam
#     samtools view -h -q 42 -o ${fileflt} ${i}
# done

# %% [markdown]
# ### BigWig

# %%
# %%bash
#
# input="/home/ug0302/CITEseq3/06_ATAC2/bamg_new"
# output="/home/ug0302/CITEseq3/06_ATAC2/bigwig_new"
# file=$(ls ${input}/*.bam)
#
# for i in $file
# do
#     filename=$(basename "$i" .bam)
#     filebw=${output}/${filename}.bw
#
#     bamCoverage --bam ${i} \
#                 -o ${filebw} \
#                 --binSize 50 \
#                 --normalizeUsing BPM \
#                 -p max
# done

# %% [markdown]
# ### Peak calling

# %%
# %%bash
#
# source activate atac_macs2
#
# input="/home/ug0302/CITEseq3/06_ATAC2/bamg_new"
# output="/home/ug0302/CITEseq3/06_ATAC2/peak"
# file=$(ls ${input}/*.bam)
#
# species="hs"
#
# for i in $file
# do
#     filename=$(basename "$i" .bam)
#     macs2 callpeak -n ${filename} \
#                    -t ${i} \
#                    -f BAMPE \
#                    --nomodel \
#                    -p 0.01 \
#                    -g ${species} \
#                    --shift -75 \
#                    --extsize 150 \
#                    --keep-dup all \
#                    --outdir ${output}
# done

# %% [markdown]
# ### Heatmap

# %%
# %%bash
#
# path_bw="/home/ug0302/CITEseq3/06_ATAC2/bigwig_new"
# file_bw=$(ls -1 ${path_bw}/*.bw | tr '\n' ' ')
#
# path_pk="/home/ug0302/CITEseq3/06_ATAC2/diffbind"
# file_pk=$(ls -1 ${path_pk}/*.bed | tr '\n' ' ')
#
# data="/home/ug0302/CITEseq3/06_ATAC2/figure/heatmap/nom.gz"
# figure1="/home/ug0302/CITEseq3/06_ATAC2/figure/heatmap/heatmap.pdf"
# figure2="/home/ug0302/CITEseq3/06_ATAC2/figure/heatmap/heatmap_stat.pdf"
#
# width=2000
# computeMatrix reference-point \
#               --referencePoint center \
#               -b ${width} -a ${width} -p max \
#               --missingDataAsZero --skipZeros \
#               -R ${file_pk} \
#               -S ${file_bw} \
#               -o ${data}
#
# color='#281A2C,#352A4A,#3F396D,#404C8B,#3E6495,#427999,#488E9E,#50A3A2,#5DBAA4,#78CEA3,#A3DEA6,#D1EDB4,#FDFECC'
#
# plotHeatmap -m ${data} \
#             -out ${figure1} \
#             --colorList ${color} \
#             --heatmapHeight 25 --heatmapWidth 5
#
# plotProfile -m ${data} \
#             -out ${figure2} \
#             --perGroup \
#             --numPlotsPerRow 2 \
#             --plotHeight 10 --plotWidth 10

# %% [markdown]
# ### WhichTF

# %%
# %%bash
#
# genome="hg38"
# input="/home/ug0302/CITEseq3/06_ATAC2/diffbind"
# output="/home/ug0302/CITEseq3/06_ATAC2/figure/whichtf"
# file=$(ls ${input}/*.bed)
#
# for i in $file
# do
#     filename=$(basename "$i" .bed)
#     output_file=${output}/TF_${filename}.tsv
#     WhichTF ${i} ${genome} --outFile ${output_file}
# done
# Out:
# /home/ug0302/.conda/envs/whichtf/bin/WhichTF:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('whichtf==0.2')
# 2023-10-25 20:01:36,112-WhichTF: [INFO] verbose_level: None
# 2023-10-25 20:01:36,112-WhichTF: [INFO] tmpdir: /tmp
# 2023-10-25 20:01:36,112-WhichTF: [INFO] settings: None
# 2023-10-25 20:01:36,112-WhichTF: [INFO] leaveTrace: False
# 2023-10-25 20:01:36,112-WhichTF: [INFO] data: /home/ug0302/ATACseq/public_data/software/whichtf/data
# 2023-10-25 20:01:36,112-WhichTF: [INFO] inFile: /home/ug0302/CITEseq3/06_ATAC2/diffbind/Conc_C50.bed
# 2023-10-25 20:01:36,112-WhichTF: [INFO] assembly: hg19
# 2023-10-25 20:01:36,112-WhichTF: [INFO] outFile: /home/ug0302/CITEseq3/06_ATAC2/figure/whichtf/TF_Conc_C50.tsv
# 2023-10-25 20:01:36,112-WhichTF: [INFO] partialScore: False
# 2023-10-25 20:01:36,112-WhichTF: [INFO] outPartialScore: None
# 2023-10-25 20:01:36,113-WhichTF: [INFO] bedtools: bedtools
# 2023-10-25 20:01:36,113-WhichTF: [INFO] overlapSelect: overlapSelect
# 2023-10-25 20:01:36,113-WhichTF: [INFO] GREATER: GREATER
# 2023-10-25 20:01:36,113-WhichTF: [INFO] termNum: 100
# 2023-10-25 20:01:36,113-WhichTF: [INFO] termMethod: bin
# 2023-10-25 20:01:36,113-WhichTF: [INFO] termFile: None
# 2023-10-25 20:01:36,113-WhichTF: [INFO] myMin: 2
# 2023-10-25 20:01:36,113-WhichTF: [INFO] myMax: 500
# 2023-10-25 20:01:36,113-WhichTF: [INFO] tfbs: PRISM
# 2023-10-25 20:01:36,113-WhichTF: [INFO] myOnt: MGIPhenotype
# 2023-10-25 20:01:36,113-WhichTF: [INFO] equal_first_n: 1
# 2023-10-25 20:01:36,113-WhichTF: [INFO] first_n_strict: False
# 2023-10-25 20:01:36,113-WhichTF: [INFO] max_tf: 10
# 2023-10-25 20:01:36,113-WhichTF: [INFO] before_hyp_jump: True
# 2023-10-25 20:01:36,113-WhichTF: [INFO] before_bin_jump: True
# 2023-10-25 20:02:02,886-run.py: [INFO] Working on score 3 of 90.
# 2023-10-25 20:02:07,689-run.py: [INFO] Working on score 4 of 90.
# 2023-10-25 20:02:12,401-run.py: [INFO] Working on score 5 of 90.
# 2023-10-25 20:02:16,607-run.py: [INFO] Working on score 6 of 90.
# 2023-10-25 20:02:20,609-run.py: [INFO] Working on score 7 of 90.
# 2023-10-25 20:02:24,710-run.py: [INFO] Working on score 8 of 90.
# 2023-10-25 20:02:28,418-run.py: [INFO] Working on score 9 of 90.
# 2023-10-25 20:02:31,851-run.py: [INFO] Working on score 10 of 90.
# 2023-10-25 20:02:35,011-run.py: [INFO] Working on score 11 of 90.
# 2023-10-25 20:02:38,087-run.py: [INFO] Working on score 12 of 90.
# 2023-10-25 20:02:41,038-run.py: [INFO] Working on score 13 of 90.
# 2023-10-25 20:02:43,847-run.py: [INFO] Working on score 14 of 90.
# 2023-10-25 20:02:46,593-run.py: [INFO] Working on score 15 of 90.
# 2023-10-25 20:02:49,264-run.py: [INFO] Working on score 16 of 90.
# 2023-10-25 20:02:51,724-run.py: [INFO] Working on score 17 of 90.
# 2023-10-25 20:02:54,049-run.py: [INFO] Working on score 18 of 90.
# 2023-10-25 20:02:56,241-run.py: [INFO] Working on score 19 of 90.
# 2023-10-25 20:02:58,330-run.py: [INFO] Working on score 20 of 90.
# 2023-10-25 20:03:00,362-run.py: [INFO] Working on score 21 of 90.
# 2023-10-25 20:03:02,252-run.py: [INFO] Working on score 22 of 90.
# 2023-10-25 20:03:04,028-run.py: [INFO] Working on score 23 of 90.
# 2023-10-25 20:03:05,700-run.py: [INFO] Working on score 24 of 90.
# 2023-10-25 20:03:07,258-run.py: [INFO] Working on score 25 of 90.
# 2023-10-25 20:03:08,820-run.py: [INFO] Working on score 26 of 90.
# 2023-10-25 20:03:10,275-run.py: [INFO] Working on score 27 of 90.
# 2023-10-25 20:03:11,651-run.py: [INFO] Working on score 28 of 90.
# 2023-10-25 20:03:12,913-run.py: [INFO] Working on score 29 of 90.
# 2023-10-25 20:03:14,095-run.py: [INFO] Working on score 30 of 90.
# 2023-10-25 20:03:15,236-run.py: [INFO] Working on score 31 of 90.
# 2023-10-25 20:03:16,335-run.py: [INFO] Working on score 32 of 90.
# 2023-10-25 20:03:17,392-run.py: [INFO] Working on score 33 of 90.
# 2023-10-25 20:03:18,417-run.py: [INFO] Working on score 34 of 90.
# 2023-10-25 20:03:19,382-run.py: [INFO] Working on score 35 of 90.
# 2023-10-25 20:03:20,263-run.py: [INFO] Working on score 36 of 90.
# 2023-10-25 20:03:21,112-run.py: [INFO] Working on score 37 of 90.
# 2023-10-25 20:03:21,925-run.py: [INFO] Working on score 38 of 90.
# 2023-10-25 20:03:22,696-run.py: [INFO] Working on score 39 of 90.
# 2023-10-25 20:03:23,440-run.py: [INFO] Working on score 40 of 90.
# 2023-10-25 20:03:24,179-run.py: [INFO] Working on score 41 of 90.
# 2023-10-25 20:03:24,870-run.py: [INFO] Working on score 42 of 90.
# 2023-10-25 20:03:25,510-run.py: [INFO] Working on score 43 of 90.
# 2023-10-25 20:03:26,109-run.py: [INFO] Working on score 44 of 90.
# 2023-10-25 20:03:26,666-run.py: [INFO] Working on score 45 of 90.
# 2023-10-25 20:03:27,210-run.py: [INFO] Working on score 46 of 90.
# 2023-10-25 20:03:27,736-run.py: [INFO] Working on score 47 of 90.
# 2023-10-25 20:03:28,241-run.py: [INFO] Working on score 48 of 90.
# 2023-10-25 20:03:28,714-run.py: [INFO] Working on score 49 of 90.
# 2023-10-25 20:03:29,162-run.py: [INFO] Working on score 50 of 90.
# 2023-10-25 20:03:29,604-run.py: [INFO] Working on score 51 of 90.
# 2023-10-25 20:03:30,003-run.py: [INFO] Working on score 52 of 90.
# 2023-10-25 20:03:30,367-run.py: [INFO] Working on score 53 of 90.
# 2023-10-25 20:03:30,690-run.py: [INFO] Working on score 54 of 90.
# 2023-10-25 20:03:30,991-run.py: [INFO] Working on score 55 of 90.
# 2023-10-25 20:03:31,271-run.py: [INFO] Working on score 56 of 90.
# 2023-10-25 20:03:31,541-run.py: [INFO] Working on score 57 of 90.
# 2023-10-25 20:03:31,785-run.py: [INFO] Working on score 58 of 90.
# 2023-10-25 20:03:32,010-run.py: [INFO] Working on score 59 of 90.
# 2023-10-25 20:03:32,222-run.py: [INFO] Working on score 60 of 90.
# 2023-10-25 20:03:32,403-run.py: [INFO] Working on score 61 of 90.
# 2023-10-25 20:03:32,565-run.py: [INFO] Working on score 62 of 90.
# 2023-10-25 20:03:32,707-run.py: [INFO] Working on score 63 of 90.
# 2023-10-25 20:03:32,834-run.py: [INFO] Working on score 64 of 90.
# 2023-10-25 20:03:32,944-run.py: [INFO] Working on score 65 of 90.
# 2023-10-25 20:03:33,042-run.py: [INFO] Working on score 66 of 90.
# 2023-10-25 20:03:33,124-run.py: [INFO] Working on score 67 of 90.
# 2023-10-25 20:03:33,197-run.py: [INFO] Working on score 68 of 90.
# 2023-10-25 20:03:33,259-run.py: [INFO] Working on score 69 of 90.
# 2023-10-25 20:03:33,313-run.py: [INFO] Working on score 70 of 90.
# 2023-10-25 20:03:33,358-run.py: [INFO] Working on score 71 of 90.
# 2023-10-25 20:03:33,399-run.py: [INFO] Working on score 72 of 90.
# 2023-10-25 20:03:33,437-run.py: [INFO] Working on score 73 of 90.
# 2023-10-25 20:03:33,469-run.py: [INFO] Working on score 74 of 90.
# 2023-10-25 20:03:33,495-run.py: [INFO] Working on score 75 of 90.
# 2023-10-25 20:03:33,514-run.py: [INFO] Working on score 76 of 90.
# 2023-10-25 20:03:33,529-run.py: [INFO] Working on score 77 of 90.
# 2023-10-25 20:03:33,540-run.py: [INFO] Working on score 78 of 90.
# 2023-10-25 20:03:33,549-run.py: [INFO] Working on score 79 of 90.
# 2023-10-25 20:03:33,555-run.py: [INFO] Working on score 80 of 90.
# 2023-10-25 20:03:33,560-run.py: [INFO] Working on score 81 of 90.
# 2023-10-25 20:03:33,564-run.py: [INFO] Working on score 82 of 90.
# 2023-10-25 20:03:33,567-run.py: [INFO] Working on score 83 of 90.
# 2023-10-25 20:03:33,570-run.py: [INFO] Working on score 84 of 90.
# 2023-10-25 20:03:33,572-run.py: [INFO] Working on score 85 of 90.
# 2023-10-25 20:03:33,574-run.py: [INFO] Working on score 86 of 90.
# 2023-10-25 20:03:33,576-run.py: [INFO] Working on score 87 of 90.
# 2023-10-25 20:03:33,579-run.py: [INFO] Working on score 88 of 90.
# 2023-10-25 20:03:33,581-run.py: [INFO] Working on score 89 of 90.
# 2023-10-25 20:03:33,583-run.py: [INFO] Working on score 90 of 90.
# 2023-10-25 20:03:33,585-run.py: [INFO] Tabulating the results
# /home/ug0302/ATACseq/public_data/software/whichtf/data/hg19/PRISM/tfbs.data.npz
# /home/ug0302/ATACseq/public_data/software/whichtf/data/hg19/PRISM/ontologies/MGIPhenotype/ont.merge.query.npz
# /home/ug0302/.conda/envs/whichtf/bin/WhichTF:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('whichtf==0.2')
# 2023-10-25 20:03:34,206-WhichTF: [INFO] verbose_level: None
# 2023-10-25 20:03:34,206-WhichTF: [INFO] tmpdir: /tmp
# 2023-10-25 20:03:34,206-WhichTF: [INFO] settings: None
# 2023-10-25 20:03:34,206-WhichTF: [INFO] leaveTrace: False
# 2023-10-25 20:03:34,206-WhichTF: [INFO] data: /home/ug0302/ATACseq/public_data/software/whichtf/data
# 2023-10-25 20:03:34,206-WhichTF: [INFO] inFile: /home/ug0302/CITEseq3/06_ATAC2/diffbind/Conc_NC.bed
# 2023-10-25 20:03:34,206-WhichTF: [INFO] assembly: hg19
# 2023-10-25 20:03:34,206-WhichTF: [INFO] outFile: /home/ug0302/CITEseq3/06_ATAC2/figure/whichtf/TF_Conc_NC.tsv
# 2023-10-25 20:03:34,206-WhichTF: [INFO] partialScore: False
# 2023-10-25 20:03:34,206-WhichTF: [INFO] outPartialScore: None
# 2023-10-25 20:03:34,206-WhichTF: [INFO] bedtools: bedtools
# 2023-10-25 20:03:34,206-WhichTF: [INFO] overlapSelect: overlapSelect
# 2023-10-25 20:03:34,206-WhichTF: [INFO] GREATER: GREATER
# 2023-10-25 20:03:34,206-WhichTF: [INFO] termNum: 100
# 2023-10-25 20:03:34,206-WhichTF: [INFO] termMethod: bin
# 2023-10-25 20:03:34,206-WhichTF: [INFO] termFile: None
# 2023-10-25 20:03:34,206-WhichTF: [INFO] myMin: 2
# 2023-10-25 20:03:34,206-WhichTF: [INFO] myMax: 500
# 2023-10-25 20:03:34,206-WhichTF: [INFO] tfbs: PRISM
# 2023-10-25 20:03:34,206-WhichTF: [INFO] myOnt: MGIPhenotype
# 2023-10-25 20:03:34,206-WhichTF: [INFO] equal_first_n: 1
# 2023-10-25 20:03:49,307-run.py: [INFO] Applying before binomial jump filter.
# 2023-10-25 20:03:49,310-run.py: [INFO] Computing scores
# 2023-10-25 20:03:49,319-run.py: [INFO] Computing pvalues for score
# 2023-10-25 20:03:49,319-run.py: [INFO] Working on score 1 of 32.
# 2023-10-25 20:03:49,963-run.py: [INFO] Working on score 2 of 32.
# 2023-10-25 20:03:50,310-run.py: [INFO] Working on score 3 of 32.
# 2023-10-25 20:03:50,521-run.py: [INFO] Working on score 4 of 32.
# 2023-10-25 20:03:50,667-run.py: [INFO] Working on score 5 of 32.
# 2023-10-25 20:03:50,801-run.py: [INFO] Working on score 6 of 32.
# 2023-10-25 20:03:50,921-run.py: [INFO] Working on score 7 of 32.
# 2023-10-25 20:03:51,020-run.py: [INFO] Working on score 8 of 32.
# 2023-10-25 20:03:51,095-run.py: [INFO] Working on score 9 of 32.
# 2023-10-25 20:03:51,157-run.py: [INFO] Working on score 10 of 32.
# 2023-10-25 20:03:51,205-run.py: [INFO] Working on score 11 of 32.
# 2023-10-25 20:03:51,244-run.py: [INFO] Working on score 12 of 32.
# 2023-10-25 20:03:51,275-run.py: [INFO] Working on score 13 of 32.
# 2023-10-25 20:03:51,303-run.py: [INFO] Working on score 14 of 32.
# 2023-10-25 20:03:51,328-run.py: [INFO] Working on score 15 of 32.
# 2023-10-25 20:03:51,347-run.py: [INFO] Working on score 16 of 32.
# 2023-10-25 20:03:51,364-run.py: [INFO] Working on score 17 of 32.
# 2023-10-25 20:03:51,380-run.py: [INFO] Working on score 18 of 32.
# 2023-10-25 20:03:51,392-run.py: [INFO] Working on score 19 of 32.
# 2023-10-25 20:03:51,402-run.py: [INFO] Working on score 20 of 32.
# 2023-10-25 20:03:51,409-run.py: [INFO] Working on score 21 of 32.
# 2023-10-25 20:03:51,415-run.py: [INFO] Working on score 22 of 32.
# 2023-10-25 20:03:51,420-run.py: [INFO] Working on score 23 of 32.
# 2023-10-25 20:03:51,423-run.py: [INFO] Working on score 24 of 32.
# 2023-10-25 20:03:51,426-run.py: [INFO] Working on score 25 of 32.
# 2023-10-25 20:03:51,429-run.py: [INFO] Working on score 26 of 32.
# 2023-10-25 20:03:51,431-run.py: [INFO] Working on score 27 of 32.
# 2023-10-25 20:03:51,435-run.py: [INFO] Working on score 28 of 32.
# 2023-10-25 20:03:51,441-run.py: [INFO] Working on score 29 of 32.
# 2023-10-25 20:03:51,446-run.py: [INFO] Working on score 30 of 32.
# 2023-10-25 20:03:51,451-run.py: [INFO] Working on score 31 of 32.
# 2023-10-25 20:03:51,457-run.py: [INFO] Working on score 32 of 32.
# 2023-10-25 20:03:51,462-run.py: [INFO] Tabulating the results
# /home/ug0302/ATACseq/public_data/software/whichtf/data/hg19/PRISM/tfbs.data.npz
# /home/ug0302/ATACseq/public_data/software/whichtf/data/hg19/PRISM/ontologies/MGIPhenotype/ont.merge.query.npz
